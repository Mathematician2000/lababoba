# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir(r'/content/drive/My Drive/LabaBoba')

# %%
# !pip install simpletransformers

# %%
from simpletransformers.language_modeling import LanguageModelingModel
from simpletransformers.language_generation import LanguageGenerationModel

# %% [markdown]
# ## Initialization

# %%
model_args = {
    'dataset_type': 'simple',
    'min_frequency': 5,
    'mlm': False,
    'num_train_epochs': 1,

    'output_dir': 'LM_outputs',
    'overwrite_output_dir': True,
}

# %%
train_text_path = 'train_text.txt'
test_text_path = 'test_text.txt'

# %%
model = LanguageModelingModel(
    'gpt2',
    'sberbank-ai/rugpt3small_based_on_gpt2',
    use_cuda=True,
    args=model_args,
)

# %% [markdown]
# ## Training

# %%
zero_eval_result = model.eval_model(test_text_path)
# Out:
# ...
# Running Evaluation:   0%|          | 0/1648 [00:00<?, ?it/s]

# %%
zero_eval_result
# Out:
# {'eval_loss': 4.274605708359514, 'perplexity': tensor(71.8518)}

# %%
model.train_model(train_text_path)
# Out:
# ...
#   0%|          | 0/52134 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Epoch 0 of 1:   0%|          | 0/6517 [00:00<?, ?it/s]
# (6517, 4.079877767969681)

# %% [markdown]
# ## Evaluation

# %%
eval_result = model.eval_model(test_text_path)
# Out:
# ...
# Running Evaluation:   0%|          | 0/1648 [00:00<?, ?it/s]

# %%
eval_result
# Out:
# {'eval_loss': 3.892442209628022, 'perplexity': tensor(49.0305)}

# %%
gen_model_args = {
    'do_sample': True,
    'max_length': 20,
    'verbose': True,
}

# %%
gen_model = LanguageGenerationModel(
    'gpt2',
    'LM_outputs',
    use_cuda=True,
    args=gen_model_args,
)

# %%
starts = [
    'Сижу я, значит, за столом, и вдруг...',
    'Чего?! Что ты несёшь? Ты ещё скажи, что',
]

gen_result = [gen_model.generate(text) for text in starts]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(*(line[0] for line in gen_result), sep='\n===\n')
# Out:
# Сижу я, значит, за столом, и вдруг... Я его вижу... Ну я его и на кухню. И он говорит: "Дура! Тебе
# ===
# Чего?! Что ты несёшь? Ты ещё скажи, что твои проблемы из-за того, что я тебя отчислил...- Сёма, а что
